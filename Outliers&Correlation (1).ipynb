# %% [markdown]
# **Tugas Statistika Terapan**
#
# Nama Kelompok:
#
# 1.   Gopi Mahendra (G1A021005)
# 2.   Nazir Mahmudi Lubis (G1A021013)

# %%
#import library yang digunakan
import pandas as pd
import pandas as pan
import numpy as num
import statistics
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
'''
Penjelasan :
Dataset yang digunakan mengenai tentang kumpulan data yang terdiri dari nilai yang diperoleh siswa dalam berbagai mata pelajaran.
Dataset ini kami peroleh dari website kaggle kemudian file csv nya kami import ke github lalu link githubnya kami load di google colab seperti 
dibawah ini.
'''
# Out:
# '\nPenjelasan :\nDataset yang digunakan mengenai tentang kumpulan data yang terdiri dari nilai yang diperoleh siswa dalam berbagai mata pelajaran.\nDataset ini kami peroleh dari website kaggle kemudian file csv nya kami import ke github lalu link githubnya kami load di google colab seperti \ndibawah ini.\n'

# %%
#load dataset menggunakan URL
dataset = pan.read_csv("https://raw.githubusercontent.com/g4mahendraa/Tugas-Statistik-Terapan./main/titanic.csv")

# %%
#URL dataset
url = "https://raw.githubusercontent.com/g4mahendraa/Tugas-Statistik-Terapan./main/titanic.csv"
exams_csv = pd.read_csv(url)

# %%
#Menampilkan 5 record teratas dari dataset yang telah di load, gunakan head()
dataset.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#Menampilkan ukuran dataset
dataset.shape
# Out:
# (891, 12)

# %%
#Menampilkan informasi column, datatype dan informasi struktur lainnya pada dataset
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#Menampilkan data statistik dari dataset
dataset.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#Menampilkan outliers dataset pada baris Age menggunakan boxplot
sample= dataset["Age"]

plt.boxplot(sample, vert=False)
plt.title("Detecting outliers using Boxplot")
plt.xlabel('Age ')
plt.show()

# %%
# cek outliers Embarked menggunakan boxplot
sns.boxplot(x='Age', data=dataset);

# %%
#Mencari nilai outliers menggunakan metode Z-scores
outliers = []
def detect_outliers_zscore(data):
    theres = 3
    mean = np.mean(data)
    std = np.std(data)
    # print(mean, std)
    for i in data:
        z_score = (i-mean)/std
        if (np.abs(z_score) > theres):
            outliers.append(i)
    return outliers# Driver code
sample_outliers = detect_outliers_zscore(sample)
print("Outliers from Z-scores method: ", sample_outliers)
# Out:
# Outliers from Z-scores method:  [80.0, 74.0]

# %%
#Mencari nilai kuartil 1, kuartil 3, dan IQR
outliers =[]
Q1 = np.quantile(dataset["Age"], .25)
Q3 = np.quantile(dataset["Age"], .75)
IQR = Q3 - Q1
print('Kuartil 1 = ', Q1)
print('Kuartil 3 = ', Q3)
print('IQR = ', IQR)

min_IQR = Q1 - 1.5 * IQR
max_IQR = Q3 + 1.5 * IQR

print('IQR minimum = ', min_IQR)
print('IQR maksimum = ', max_IQR)

nilai_min = np.min(dataset["Age"])
nilai_max = np.max(dataset["Age"])
# Out:
# Kuartil 1 =  nan
# Kuartil 3 =  nan
# IQR =  nan
# IQR minimum =  nan
# IQR maksimum =  nan

# %%
#Mencari Outliers pada dataset menggunakan IQR
low_out = []
high_out = []

for i in dataset["Age"]:
    if (i < min_IQR):
        low_out.append(i)
    if (i > max_IQR):
        high_out.append(i)

print('Low outlier : ', low_out)
print('High outlier : ', high_out)
# Out:
# Low outlier :  []
# High outlier :  []

# %%
#Menghilangkan outliers pada dataset menggunakan trimming
dataset_no_outlier = dataset[(dataset["Age"] > nilai_min) & (dataset["Age"] <= nilai_max)]
dataset_no_outlier
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Menentukan flooring and capping pada dataset
# Computing 10th, 90th percentiles and replacing the outliers
tenth_percentile = np.percentile(sample, 10)
ninetieth_percentile = np.percentile(sample, 90)
print(tenth_percentile, ninetieth_percentile)
b = np.where(sample<tenth_percentile, tenth_percentile, sample)
b = np.where(b>ninetieth_percentile, ninetieth_percentile, b)
print("New array:",b)
# Out:
# nan nan
# New array: [22.   38.   26.   35.   35.     nan 54.    2.   27.   14.    4.   58.
#  20.   39.   14.   55.    2.     nan 31.     nan 35.   34.   15.   28.
#   8.   38.     nan 19.     nan   nan 40.     nan   nan 66.   28.   42.
#    nan 21.   18.   14.   40.   27.     nan  3.   19.     nan   nan   nan
#    nan 18.    7.   21.   49.   29.   65.     nan 21.   28.5   5.   11.
#  22.   38.   45.    4.     nan   nan 29.   19.   17.   26.   32.   16.
#  21.   26.   32.   25.     nan   nan  0.83 30.   22.   29.     nan 28.
#  17.   33.   16.     nan 23.   24.   29.   20.   46.   26.   59.     nan
#  71.   23.   34.   34.   28.     nan 21.   33.   37.   28.   21.     nan
#  38.     nan 47.   14.5  22.   20.   17.   21.   70.5  29.   24.    2.
#  21.     nan 32.5  32.5  54.   12.     nan 24.     nan 45.   33.   20.
#  47.   29.   25.   23.   19.   37.   16.   24.     nan 22.   24.   19.
#  18.   19.   27.    9.   36.5  42.   51.   22.   55.5  40.5    nan 51.
# ...

# %%
# Replace with median
median = np.median(sample)
for i in sample_outliers:
    c = np.where(sample==i, 14,sample)
print("Sample: ", sample)
print("New array: ",c)
# Out:
# Sample:  0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64
# New array:  [22.   38.   26.   35.   35.     nan 54.    2.   27.   14.    4.   58.
#  20.   39.   14.   55.    2.     nan 31.     nan 35.   34.   15.   28.
#   8.   38.     nan 19.     nan   nan 40.     nan   nan 66.   28.   42.
#    nan 21.   18.   14.   40.   27.     nan  3.   19.     nan   nan   nan
#    nan 18.    7.   21.   49.   29.   65.     nan 21.   28.5   5.   11.
#  22.   38.   45.    4.     nan   nan 29.   19.   17.   26.   32.   16.
#  21.   26.   32.   25.     nan   nan  0.83 30.   22.   29.     nan 28.
#  17.   33.   16.     nan 23.   24.   29.   20.   46.   26.   59.     nan
#  71.   23.   34.   34.   28.     nan 21.   33.   37.   28.   21.     nan
#  38.     nan 47.   14.5  22.   20.   17.   21.   70.5  29.   24.    2.
# ...

# %%
# Replace with mean
mean = np.mean(sample)
for i in sample_outliers:
    c = np.where(sample==i, 14,sample)
print("Sample: ", sample)
print("New array: ",c)
# Out:
# Sample:  0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64
# New array:  [22.   38.   26.   35.   35.     nan 54.    2.   27.   14.    4.   58.
#  20.   39.   14.   55.    2.     nan 31.     nan 35.   34.   15.   28.
#   8.   38.     nan 19.     nan   nan 40.     nan   nan 66.   28.   42.
#    nan 21.   18.   14.   40.   27.     nan  3.   19.     nan   nan   nan
#    nan 18.    7.   21.   49.   29.   65.     nan 21.   28.5   5.   11.
#  22.   38.   45.    4.     nan   nan 29.   19.   17.   26.   32.   16.
#  21.   26.   32.   25.     nan   nan  0.83 30.   22.   29.     nan 28.
#  17.   33.   16.     nan 23.   24.   29.   20.   46.   26.   59.     nan
#  71.   23.   34.   34.   28.     nan 21.   33.   37.   28.   21.     nan
#  38.     nan 47.   14.5  22.   20.   17.   21.   70.5  29.   24.    2.
# ...

# %%
#Menampilkan boxplot yang telah bebas dari outliers 
dataset_no_outlier.boxplot(["Age"],vert=False)
plt.title("Boxplot of the sample after treating the outliers")
plt.xlabel("Age")
# Out:
# Text(0.5, 0, 'Age')

# %% [markdown]
# ### Correlation Analysis (bivariate)
#
# > Pemblokiran indentasi

# %%
#Menampilkan korelasi antar kolom numerik
dataset.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
#Menampilkan korelasi dataset menggunakan heatmap, yang dimana semakin tinggi angka suatu kelompok data maka warnanya akan semakin gelap
sns.heatmap(dataset.corr())
plt.show()
